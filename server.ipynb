# %%
from flask import Flask, request, jsonify
import joblib
import os
import numpy as np

app = Flask(__name__)

# Directory to store uploaded models
MODEL_DIR = "models"
os.makedirs(MODEL_DIR, exist_ok=True)


model = None

@app.route("/deploy-model", methods=["POST"])
def deploy_model():
    global model

    if 'model_file' not in request.files:
        return jsonify({"error": "No model file provided."}), 400

    model_file = request.files['model_file']
    if model_file.filename == '':
        return jsonify({"error": "Empty filename."}), 400

    # Save and load the model
    model_path = os.path.join(MODEL_DIR, model_file.filename)
    model_file.save(model_path)
    try:
        model = joblib.load(model_path)
        return jsonify({"message": f"Model '{model_file.filename}' deployed successfully."}), 200
    except Exception as e:
        return jsonify({"error": f"Failed to load model: {str(e)}"}), 500

@app.route("/predict", methods=["POST"])
def predict():
    global model
    if model is None:
        return jsonify({"error": "No model is currently deployed."}), 400

    data = request.json
    if not data or "input" not in data:
        return jsonify({"error": "Missing 'input' in request body."}), 400

    try:
        input_data = np.array(data["input"]).reshape(1, -1)
        prediction = model.predict(input_data)
        return jsonify({"prediction": prediction.tolist()})
    except Exception as e:
        return jsonify({"error": f"Prediction failed: {str(e)}"}), 500

@app.route("/status", methods=["GET"])
def status():
    if model is None:
        return jsonify({"model_status": "No model deployed."}), 200
    else:
        return jsonify({"model_status": "Model is deployed and ready."}), 200

if __name__ == "__main__":
    app.run(host="0.0.0.0", port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.166:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [07/Sep/2025 19:58:57] "POST /deploy-model HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:02:03] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:03:20] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:03:49] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:04:44] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:04:51] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:04:57] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:05:02] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:05:12] "POST /predict HTTP/1.1" 200 -
# 192.168.1.166 - - [07/Sep/2025 20:05:18] "POST /predict HTTP/1.1" 400 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:05:21] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:05:27] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:06:04] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:06:20] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:06:23] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:06:49] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:06:52] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:06:56] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:07:00] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:07:04] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Sep/2025 20:07:20] "POST /deploy-model HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:07:24] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Sep/2025 20:07:50] "POST /deploy-model HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 192.168.1.166 - - [07/Sep/2025 20:07:53] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Sep/2025 20:08:01] "POST /deploy-model HTTP/1.1" 200 -
# 192.168.1.166 - - [07/Sep/2025 20:08:06] "POST /predict HTTP/1.1" 200 -
# 192.168.1.166 - - [07/Sep/2025 20:08:13] "POST /predict HTTP/1.1" 200 -
# 192.168.1.166 - - [07/Sep/2025 20:08:13] "POST /predict HTTP/1.1" 200 -
# 192.168.1.166 - - [07/Sep/2025 20:08:14] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:20] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:21] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:22] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:23] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:24] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:25] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:26] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:27] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:28] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:29] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:29] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:30] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:31] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:31] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:32] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:33] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:34] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:35] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:36] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:38] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:39] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:40] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:42] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:43] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:44] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:45] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:47] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:48] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:48] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:49] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:50] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:51] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:51] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:52] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:53] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:54] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:55] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:56] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:57] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:26:59] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:00] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:01] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:02] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:04] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:05] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:06] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:47] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:48] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:49] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:49] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:50] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:51] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:52] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:53] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:53] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:54] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:55] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:55] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:56] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:57] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:58] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:27:59] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:28:00] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:28:01] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:28:03] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:28:04] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:28:47] "POST /predict HTTP/1.1" 500 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:44] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:44] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:45] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:46] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:47] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:48] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:50] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:51] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:52] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:54] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:55] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:56] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:58] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:30:59] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:00] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:01] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:02] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:03] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:04] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:04] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:05] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:06] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:07] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:07] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:08] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:09] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:10] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:12] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:31:13] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:34:47] "POST /predict HTTP/1.1" 500 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:35:27] "POST /predict HTTP/1.1" 500 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:36:34] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:36:40] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:36:45] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:36:51] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:36:56] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:37:02] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:37:07] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:37:12] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:37:18] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:37:23] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:37:29] "POST /predict HTTP/1.1" 200 -
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 10.172.32.86 - - [06/Aug/2025 15:37:34] "POST /predict HTTP/1.1" 200 -
